# %%
# %load_ext autoreload
# %autoreload 2
# %env CUDA_VISIBLE_DEVICES=1
import matplotlib.pyplot as plt
from utils import get_path
from io_utils import load_multiple_res
from pd_utils import get_outlier_scores_best_auc, filter_dgms
import os
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: CUDA_VISIBLE_DEVICES=1

# %%
style_file = "mpl_style.txt"
plt.style.use(style_file)

# %%
root_path = get_path("data")
fig_path = os.path.join(root_path, "figures")

# %% [markdown]
# # Figs with many methods on toy data

# %%
distances = {
    "euclidean": [{}],
    "fermat": [
               {"p": 2},
               {"p": 3},
               {"p": 5},
               {"p": 7}
               ],
    "dtm" : [
            {"k": 4, "p_dtm": 2, "p_radius": 1},
            {"k": 4, "p_dtm": np.inf, "p_radius": 1},
            {"k": 15, "p_dtm": 2, "p_radius": 1},
            {"k": 15, "p_dtm": np.inf, "p_radius": 1},
            {"k": 100, "p_dtm": 2, "p_radius": 1},
            {"k": 100, "p_dtm": np.inf, "p_radius": 1},

            {"k": 4, "p_dtm": 2, "p_radius": 2},
            {"k": 4, "p_dtm": np.inf, "p_radius": 2},
            {"k": 15, "p_dtm": 2, "p_radius": 2},
            {"k": 15, "p_dtm": np.inf, "p_radius": 2},
            {"k": 100, "p_dtm": 2, "p_radius": 2}, 
            {"k": 100, "p_dtm": np.inf, "p_radius": 2},

            {"k": 4, "p_dtm": 2, "p_radius": np.inf},
            {"k": 4, "p_dtm": np.inf, "p_radius": np.inf}, 
            {"k": 15, "p_dtm": 2, "p_radius": np.inf},
            {"k": 15, "p_dtm": np.inf, "p_radius": np.inf},
            {"k": 100, "p_dtm": 2, "p_radius": np.inf},
            {"k": 100, "p_dtm": np.inf, "p_radius": np.inf},
    ],
    "core": [
        {"k": 15},
        {"k": 100}
    ],
    "sknn_dist": [
        {"k": 15},
        {"k": 100}
    ],
    "tsne": [
         {"perplexity": 30},
         {"perplexity": 200},
         {"perplexity": 333}
    ],
    "umap": [
         {"k": 100, "use_rho": True, "include_self": True},
         {"k": 999, "use_rho": True, "include_self": True},
    ],
    "tsne_embd": [
        {"perplexity": 8, "n_epochs": 500, "n_early_epochs": 250, "rescale_tsne": True},
        {"perplexity": 30, "n_epochs": 500, "n_early_epochs": 250, "rescale_tsne": True},
        {"perplexity": 333, "n_epochs": 500, "n_early_epochs": 250, "rescale_tsne": True}
    ],
    "umap_embd": [
        {"k": 15, "n_epochs": 750, "min_dist": 0.1, "metric": "euclidean"},
        {"k": 100, "n_epochs": 750, "min_dist": 0.1, "metric": "euclidean"},
        {"k": 999, "n_epochs": 750, "min_dist": 0.1, "metric": "euclidean"},
    ],
    "eff_res": [
        {"corrected": True, "weighted": False, "k": 15, "disconnect": True},
        {"corrected": True, "weighted": False, "k": 100, "disconnect": True,}
    ],
    "diffusion": [
        {"k": 15, "t": 8, "kernel": "sknn", "include_self": False},
        {"k": 100, "t": 8, "kernel": "sknn", "include_self": False},
        {"k": 15, "t": 64, "kernel": "sknn", "include_self": False},
        {"k": 100, "t": 64, "kernel": "sknn", "include_self": False},
    ],
    "spectral": [
        {"k": 15, "normalization": "none", "n_evecs": 2, "weighted": False},
        {"k": 15, "normalization": "none", "n_evecs": 5, "weighted": False},
        {"k": 15, "normalization": "none", "n_evecs": 10, "weighted": False},
    ],
}

n = 1000
sigmas = np.linspace(0.0, 0.4, 33)[:-4]
sigmas = np.array([np.format_float_positional(sigma, precision=4, unique=True, trim='0') for sigma in sigmas]).astype(float)
seeds = [0, 1, 2]

# %% [markdown]
# ## Circle

# %%
dataset = "toy_circle"

# %% [markdown]
# ### d = 50

# %%
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with toy_circle 50 euclidean
# Done with toy_circle 50 fermat_p_2
# Done with toy_circle 50 fermat_p_3
# Done with toy_circle 50 fermat_p_5
# Done with toy_circle 50 fermat_p_7
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 core_k_15
# Done with toy_circle 50 core_k_100
# Done with toy_circle 50 sknn_dist_k_15
# Done with toy_circle 50 sknn_dist_k_100
# Done with toy_circle 50 tsne_perplexity_30
# Done with toy_circle 50 tsne_perplexity_200
# Done with toy_circle 50 tsne_perplexity_333
# Done with toy_circle 50 umap_k_100_use_rho_True_include_self_True
# Done with toy_circle 50 umap_k_999_use_rho_True_include_self_True
# Done with toy_circle 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with toy_circle 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with toy_circle 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores, best_aucs = get_outlier_scores_best_auc(all_res, dim=1, n_features=1)

# %%
best_aucs["dtm"]
# Out:
# {'run': 'dtm_k_4_p_dtm_2_p_radius_1', 'auc': 0.34099387742772014}

# %%
# only keep the dtm runs with the best auc for each p_radius
filter_dtm_dists(outlier_scores)
# Out:
# dict_keys(['dtm_k_4_p_dtm_2_p_radius_1', 'dtm_k_4_p_dtm_2_p_radius_2', 'dtm_k_4_p_dtm_2_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores, sigmas=sigmas, ylabel="Loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_dob.pdf")

# %% [markdown]
# ### d=2

# %%
embd_dim = 2
distances["sknn_dist"] = [{"k": 100}]  # k=15 gave convergence issues with the shortest path solver
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with toy_circle 2 euclidean
# Done with toy_circle 2 fermat_p_2
# Done with toy_circle 2 fermat_p_3
# Done with toy_circle 2 fermat_p_5
# Done with toy_circle 2 fermat_p_7
# Done with toy_circle 2 dtm_k_4_p_dtm_2_p_radius_1
# Done with toy_circle 2 dtm_k_4_p_dtm_inf_p_radius_1
# Done with toy_circle 2 dtm_k_15_p_dtm_2_p_radius_1
# Done with toy_circle 2 dtm_k_15_p_dtm_inf_p_radius_1
# Done with toy_circle 2 dtm_k_100_p_dtm_2_p_radius_1
# Done with toy_circle 2 dtm_k_100_p_dtm_inf_p_radius_1
# Done with toy_circle 2 dtm_k_4_p_dtm_2_p_radius_2
# Done with toy_circle 2 dtm_k_4_p_dtm_inf_p_radius_2
# Done with toy_circle 2 dtm_k_15_p_dtm_2_p_radius_2
# Done with toy_circle 2 dtm_k_15_p_dtm_inf_p_radius_2
# Done with toy_circle 2 dtm_k_100_p_dtm_2_p_radius_2
# Done with toy_circle 2 dtm_k_100_p_dtm_inf_p_radius_2
# Done with toy_circle 2 dtm_k_4_p_dtm_2_p_radius_inf
# Done with toy_circle 2 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with toy_circle 2 dtm_k_15_p_dtm_2_p_radius_inf
# Done with toy_circle 2 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with toy_circle 2 dtm_k_100_p_dtm_2_p_radius_inf
# Done with toy_circle 2 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with toy_circle 2 core_k_15
# Done with toy_circle 2 core_k_100
# Done with toy_circle 2 sknn_dist_k_100
# Done with toy_circle 2 tsne_perplexity_30
# Done with toy_circle 2 tsne_perplexity_200
# Done with toy_circle 2 tsne_perplexity_333
# Done with toy_circle 2 umap_k_100_use_rho_True_include_self_True
# Done with toy_circle 2 umap_k_999_use_rho_True_include_self_True
# Done with toy_circle 2 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 2 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 2 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 2 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 2 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 2 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 2 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with toy_circle 2 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with toy_circle 2 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with toy_circle 2 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with toy_circle 2 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with toy_circle 2 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with toy_circle 2 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with toy_circle 2 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with toy_circle 2 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores, best_aucs = get_outlier_scores_best_auc(all_res, dim=1, n_features=1)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores)
# Out:
# dict_keys(['dtm_k_100_p_dtm_inf_p_radius_1', 'dtm_k_100_p_dtm_inf_p_radius_2', 'dtm_k_15_p_dtm_inf_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores, sigmas=sigmas, ylabel="Loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_dob.pdf")

# %% [markdown]
# ### d=50 no filtering

# %%
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with toy_circle 50 euclidean
# Done with toy_circle 50 fermat_p_2
# Done with toy_circle 50 fermat_p_3
# Done with toy_circle 50 fermat_p_5
# Done with toy_circle 50 fermat_p_7
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with toy_circle 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with toy_circle 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with toy_circle 50 core_k_15
# Done with toy_circle 50 core_k_100
# Done with toy_circle 50 sknn_dist_k_100
# Done with toy_circle 50 tsne_perplexity_30
# Done with toy_circle 50 tsne_perplexity_200
# Done with toy_circle 50 tsne_perplexity_333
# Done with toy_circle 50 umap_k_100_use_rho_True_include_self_True
# Done with toy_circle 50 umap_k_999_use_rho_True_include_self_True
# Done with toy_circle 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_circle 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_circle 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with toy_circle 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with toy_circle 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with toy_circle 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with toy_circle 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# compute outlier scores
outlier_scores, best_aucs = get_outlier_scores_best_auc(all_res, dim=1, n_features=1)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores)
# Out:
# dict_keys(['dtm_k_100_p_dtm_2_p_radius_1', 'dtm_k_100_p_dtm_2_p_radius_2', 'dtm_k_4_p_dtm_inf_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores, sigmas=sigmas, ylabel="Loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many.pdf")

# %% [markdown]
# # Eyeglasses

# %%
dataset = "eyeglasses"
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas[:13], seeds=seeds, n_threads=10)
# Out:
# Done with eyeglasses 50 euclidean
# Done with eyeglasses 50 fermat_p_2
# Done with eyeglasses 50 fermat_p_3
# Done with eyeglasses 50 fermat_p_5
# Done with eyeglasses 50 fermat_p_7
# Done with eyeglasses 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with eyeglasses 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with eyeglasses 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with eyeglasses 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with eyeglasses 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with eyeglasses 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with eyeglasses 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with eyeglasses 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with eyeglasses 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with eyeglasses 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with eyeglasses 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with eyeglasses 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with eyeglasses 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with eyeglasses 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with eyeglasses 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with eyeglasses 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with eyeglasses 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with eyeglasses 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with eyeglasses 50 core_k_15
# Done with eyeglasses 50 core_k_100
# Done with eyeglasses 50 sknn_dist_k_100
# Done with eyeglasses 50 tsne_perplexity_30
# Done with eyeglasses 50 tsne_perplexity_200
# Done with eyeglasses 50 tsne_perplexity_333
# Done with eyeglasses 50 umap_k_100_use_rho_True_include_self_True
# Done with eyeglasses 50 umap_k_999_use_rho_True_include_self_True
# Done with eyeglasses 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with eyeglasses 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with eyeglasses 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with eyeglasses 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with eyeglasses 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with eyeglasses 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with eyeglasses 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with eyeglasses 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with eyeglasses 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with eyeglasses 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with eyeglasses 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with eyeglasses 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with eyeglasses 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with eyeglasses 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with eyeglasses 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores, best_aucs = get_outlier_scores_best_auc(all_res, dim=1, n_features=1)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores)
# Out:
# dict_keys(['dtm_k_100_p_dtm_2_p_radius_1', 'dtm_k_15_p_dtm_2_p_radius_2', 'dtm_k_4_p_dtm_2_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores, sigmas=sigmas[:13], ylabel="Loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_dob.pdf")

# %% [markdown]
# # Linked circles

# %%
dataset = "inter_circles"
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with inter_circles 50 euclidean
# Done with inter_circles 50 fermat_p_2
# Done with inter_circles 50 fermat_p_3
# Done with inter_circles 50 fermat_p_5
# Done with inter_circles 50 fermat_p_7
# Done with inter_circles 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with inter_circles 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with inter_circles 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with inter_circles 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with inter_circles 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with inter_circles 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with inter_circles 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with inter_circles 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with inter_circles 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with inter_circles 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with inter_circles 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with inter_circles 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with inter_circles 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with inter_circles 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with inter_circles 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with inter_circles 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with inter_circles 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with inter_circles 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with inter_circles 50 core_k_15
# Done with inter_circles 50 core_k_100
# Done with inter_circles 50 sknn_dist_k_100
# Done with inter_circles 50 tsne_perplexity_30
# Done with inter_circles 50 tsne_perplexity_200
# Done with inter_circles 50 tsne_perplexity_333
# Done with inter_circles 50 umap_k_100_use_rho_True_include_self_True
# Done with inter_circles 50 umap_k_999_use_rho_True_include_self_True
# Done with inter_circles 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with inter_circles 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with inter_circles 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with inter_circles 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with inter_circles 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with inter_circles 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with inter_circles 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with inter_circles 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with inter_circles 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with inter_circles 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with inter_circles 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with inter_circles 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with inter_circles 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with inter_circles 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with inter_circles 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores, best_aucs = get_outlier_scores_best_auc(all_res, dim=1, n_features=2)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores)
# Out:
# dict_keys(['dtm_k_15_p_dtm_inf_p_radius_1', 'dtm_k_15_p_dtm_inf_p_radius_2', 'dtm_k_15_p_dtm_2_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores, sigmas=sigmas, ylabel="2 loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_dob.pdf")

# %% [markdown]
# # Sphere

# %%
dataset = "toy_sphere"
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with toy_sphere 50 euclidean
# Done with toy_sphere 50 fermat_p_2
# Done with toy_sphere 50 fermat_p_3
# Done with toy_sphere 50 fermat_p_5
# Done with toy_sphere 50 fermat_p_7
# Done with toy_sphere 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with toy_sphere 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with toy_sphere 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with toy_sphere 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with toy_sphere 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with toy_sphere 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with toy_sphere 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with toy_sphere 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with toy_sphere 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with toy_sphere 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with toy_sphere 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with toy_sphere 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with toy_sphere 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with toy_sphere 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with toy_sphere 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with toy_sphere 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with toy_sphere 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with toy_sphere 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with toy_sphere 50 core_k_15
# Done with toy_sphere 50 core_k_100
# Done with toy_sphere 50 sknn_dist_k_100
# Done with toy_sphere 50 tsne_perplexity_30
# Done with toy_sphere 50 tsne_perplexity_200
# Done with toy_sphere 50 tsne_perplexity_333
# Done with toy_sphere 50 umap_k_100_use_rho_True_include_self_True
# Done with toy_sphere 50 umap_k_999_use_rho_True_include_self_True
# Done with toy_sphere 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_sphere 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_sphere 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with toy_sphere 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_sphere 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_sphere 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with toy_sphere 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with toy_sphere 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with toy_sphere 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with toy_sphere 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with toy_sphere 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with toy_sphere 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with toy_sphere 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with toy_sphere 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with toy_sphere 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)
all_res = filter_dgms(all_res, dim=2, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores_1, best_aucs_1 = get_outlier_scores_best_auc(all_res, dim=1, n_features=1)
outlier_scores_2, best_aucs_2 = get_outlier_scores_best_auc(all_res, dim=2, n_features=1)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores_1)
filter_dtm_dists(outlier_scores_2)
# Out:
# dict_keys(['dtm_k_15_p_dtm_inf_p_radius_1', 'dtm_k_15_p_dtm_inf_p_radius_2', 'dtm_k_4_p_dtm_inf_p_radius_inf'])
# dict_keys(['dtm_k_4_p_dtm_2_p_radius_1', 'dtm_k_4_p_dtm_inf_p_radius_2', 'dtm_k_4_p_dtm_2_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores_1, sigmas=sigmas, ylabel="Loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_1D_dob.pdf")

# %%
plot_many_dists(outlier_scores=outlier_scores_2, sigmas=sigmas, ylabel="Void detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_2D_dob.pdf")

# %% [markdown]
# # Torus

# %%
dataset = "torus"
embd_dim = 50
all_res = load_multiple_res(datasets=dataset, distances=distances, root_path=root_path, n=n, embd_dims=embd_dim, sigmas=sigmas, seeds=seeds, n_threads=10)
# Out:
# Done with torus 50 euclidean
# Done with torus 50 fermat_p_2
# Done with torus 50 fermat_p_3
# Done with torus 50 fermat_p_5
# Done with torus 50 fermat_p_7
# Done with torus 50 dtm_k_4_p_dtm_2_p_radius_1
# Done with torus 50 dtm_k_4_p_dtm_inf_p_radius_1
# Done with torus 50 dtm_k_15_p_dtm_2_p_radius_1
# Done with torus 50 dtm_k_15_p_dtm_inf_p_radius_1
# Done with torus 50 dtm_k_100_p_dtm_2_p_radius_1
# Done with torus 50 dtm_k_100_p_dtm_inf_p_radius_1
# Done with torus 50 dtm_k_4_p_dtm_2_p_radius_2
# Done with torus 50 dtm_k_4_p_dtm_inf_p_radius_2
# Done with torus 50 dtm_k_15_p_dtm_2_p_radius_2
# Done with torus 50 dtm_k_15_p_dtm_inf_p_radius_2
# Done with torus 50 dtm_k_100_p_dtm_2_p_radius_2
# Done with torus 50 dtm_k_100_p_dtm_inf_p_radius_2
# Done with torus 50 dtm_k_4_p_dtm_2_p_radius_inf
# Done with torus 50 dtm_k_4_p_dtm_inf_p_radius_inf
# Done with torus 50 dtm_k_15_p_dtm_2_p_radius_inf
# Done with torus 50 dtm_k_15_p_dtm_inf_p_radius_inf
# Done with torus 50 dtm_k_100_p_dtm_2_p_radius_inf
# Done with torus 50 dtm_k_100_p_dtm_inf_p_radius_inf
# Done with torus 50 core_k_15
# Done with torus 50 core_k_100
# Done with torus 50 sknn_dist_k_100
# Done with torus 50 tsne_perplexity_30
# Done with torus 50 tsne_perplexity_200
# Done with torus 50 tsne_perplexity_333
# Done with torus 50 umap_k_100_use_rho_True_include_self_True
# Done with torus 50 umap_k_999_use_rho_True_include_self_True
# Done with torus 50 tsne_embd_perplexity_8_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with torus 50 tsne_embd_perplexity_30_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with torus 50 tsne_embd_perplexity_333_n_epochs_500_n_early_epochs_250_rescale_tsne_True
# Done with torus 50 umap_embd_k_15_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with torus 50 umap_embd_k_100_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with torus 50 umap_embd_k_999_n_epochs_750_min_dist_0.1_metric_euclidean
# Done with torus 50 eff_res_corrected_True_weighted_False_k_15_disconnect_True
# Done with torus 50 eff_res_corrected_True_weighted_False_k_100_disconnect_True
# Done with torus 50 diffusion_k_15_t_8_kernel_sknn_include_self_False
# Done with torus 50 diffusion_k_100_t_8_kernel_sknn_include_self_False
# Done with torus 50 diffusion_k_15_t_64_kernel_sknn_include_self_False
# Done with torus 50 diffusion_k_100_t_64_kernel_sknn_include_self_False
# Done with torus 50 spectral_k_15_normalization_none_n_evecs_2_weighted_False
# Done with torus 50 spectral_k_15_normalization_none_n_evecs_5_weighted_False
# Done with torus 50 spectral_k_15_normalization_none_n_evecs_10_weighted_False

# %%
# filtering 
dob = 1.25
all_res = filter_dgms(all_res, dim=1, dob=dob, binary=True)
all_res = filter_dgms(all_res, dim=2, dob=dob, binary=True)

# %%
# compute outlier scores
outlier_scores_1, best_aucs_1 = get_outlier_scores_best_auc(all_res, dim=1, n_features=2)
outlier_scores_2, best_aucs_2 = get_outlier_scores_best_auc(all_res, dim=2, n_features=1)

# %%
# delete all but the best run for dtm for each p_radius
filter_dtm_dists(outlier_scores_1)
filter_dtm_dists(outlier_scores_2)
# Out:
# dict_keys(['dtm_k_4_p_dtm_2_p_radius_1', 'dtm_k_4_p_dtm_2_p_radius_2', 'dtm_k_4_p_dtm_2_p_radius_inf'])
# dict_keys(['dtm_k_4_p_dtm_2_p_radius_1', 'dtm_k_4_p_dtm_2_p_radius_2', 'dtm_k_4_p_dtm_2_p_radius_inf'])

# %%
plot_many_dists(outlier_scores=outlier_scores_1, sigmas=sigmas, ylabel="2 loop detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_1D_dob.pdf")

# %%
plot_many_dists(outlier_scores=outlier_scores_2, sigmas=sigmas, ylabel="Void detection score", fig_path=fig_path, fig_title=f"fig_{dataset}_{embd_dim}_many_2D_dob.pdf")
